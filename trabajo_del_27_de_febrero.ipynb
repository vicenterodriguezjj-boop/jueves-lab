# %% [markdown]
#  datos casas india
#
# ActividadesLab
#
# 1. Crear un Dataframe.
#
# 2. Dar toda la información.
#
# 3. Crear una máscara y van a filtrar por precio ›= 10,000
#
# 4. ¿Cuántas son inferiores a 10,000?
#
# 5. Crear un nuevo Dataframe a partir de los valores >= 10000
#
# 6. Dar toda la información.
#
# 7. Crear una serie con todas las direcciones de las casas

# %%
#crear un dataframe
# %pip install pandas
import pandas as pd

# %%
datos_casa_india = pd.read_csv("/content/datos_casa_india/datos_casas_india.csv", index_col=0)
datos_casa_india.head()
# Out:
#                            house_size           location   city   latitude  \
# house_type
# 1 RK Studio Apartment       400 sq ft            Kalkaji  Delhi  28.545561
# 1 RK Studio Apartment       400 sq ft  Mansarover Garden  Delhi  28.643259
# 2 BHK Independent Floor     500 sq ft        Uttam Nagar  Delhi  28.618677
# 3 BHK Independent House   1,020 sq ft         Model Town  Delhi  28.712898
# 2 BHK Apartment             810 sq ft   Sector 13 Rohini  Delhi  28.723539
#
#                           longitude  price currency  numBathrooms  \
# house_type
# 1 RK Studio Apartment     77.254349  22000      INR           1.0
# 1 RK Studio Apartment     77.132828  20000      INR           1.0
# 2 BHK Independent Floor   77.053352   8500      INR           1.0
# 3 BHK Independent House   77.180000  48000      INR           3.0
# 2 BHK Apartment           77.131424  20000      INR           2.0
#
#                           numBalconies isNegotiable  priceSqFt  \
# house_type
# ...

# %%
display(datos_casa_india) #dar toda la informacion
# Out:
#                            house_size            location   city   latitude  \
# house_type
# 1 RK Studio Apartment       400 sq ft             Kalkaji  Delhi  28.545561
# 1 RK Studio Apartment       400 sq ft   Mansarover Garden  Delhi  28.643259
# 2 BHK Independent Floor     500 sq ft         Uttam Nagar  Delhi  28.618677
# 3 BHK Independent House   1,020 sq ft          Model Town  Delhi  28.712898
# 2 BHK Apartment             810 sq ft    Sector 13 Rohini  Delhi  28.723539
# ...                               ...                 ...    ...        ...
# 4 BHK Villa               5,896 sq ft        Sunder Nagar  Delhi  28.618437
# 5 BHK Independent House   6,521 sq ft        Sunder Nagar  Delhi  28.618437
# 3 BHK Independent Floor   1,855 sq ft  New Friends Colony  Delhi  28.567051
# 3 BHK Independent Floor   2,856 sq ft  New Friends Colony  Delhi  28.567051
# 3 BHK Independent Floor   2,856 sq ft  New Friends Colony  Delhi  28.567051
#
# ...

# %%
datos_casa_india.shape # para ver todo el contenido (comprobar)
# Out:
# (5000, 15)

# %%
#crear una mascara y filtrar por precio los que sean igual o mayores de 10,000

# %%
mask_precio = datos_casa_india['price'] >= 10000
datos_casa_india_filtrado = datos_casa_india[mask_precio]
display(datos_casa_india_filtrado)
# Out:
#                            house_size            location   city   latitude  \
# house_type
# 1 RK Studio Apartment       400 sq ft             Kalkaji  Delhi  28.545561
# 1 RK Studio Apartment       400 sq ft   Mansarover Garden  Delhi  28.643259
# 3 BHK Independent House   1,020 sq ft          Model Town  Delhi  28.712898
# 2 BHK Apartment             810 sq ft    Sector 13 Rohini  Delhi  28.723539
# 3 BHK Apartment             750 sq ft           DLF Farms  Delhi  28.488153
# ...                               ...                 ...    ...        ...
# 4 BHK Villa               5,896 sq ft        Sunder Nagar  Delhi  28.618437
# 5 BHK Independent House   6,521 sq ft        Sunder Nagar  Delhi  28.618437
# 3 BHK Independent Floor   1,855 sq ft  New Friends Colony  Delhi  28.567051
# 3 BHK Independent Floor   2,856 sq ft  New Friends Colony  Delhi  28.567051
# 3 BHK Independent Floor   2,856 sq ft  New Friends Colony  Delhi  28.567051
#
# ...

# %%
#cuantas son inferiores a 10,000
mask_precio = datos_casa_india['price'] <= 10000
datos_casa_india_filtrado = datos_casa_india[mask_precio]
display(datos_casa_india_filtrado)
# Out:
#                            house_size     location   city   latitude  \
# house_type
# 2 BHK Independent Floor     500 sq ft  Uttam Nagar  Delhi  28.618677
# 2 BHK Apartment           1,162 sq ft  Gagan Vihar  Delhi  28.708557
# 1 BHK Independent Floor     700 sq ft  Uttam Nagar  Delhi  28.619457
# 1 BHK Independent Floor     360 sq ft     Badarpur  Delhi  28.491892
# 2 BHK Apartment             480 sq ft  Uttam Nagar  Delhi  28.618303
# ...                               ...          ...    ...        ...
# 2 BHK Independent House     445 sq ft       Burari  Delhi  28.760500
# 2 BHK Apartment           1,800 sq ft  Uttam Nagar  Delhi  28.618809
# 1 BHK Independent Floor     500 sq ft        Saket  Delhi  28.523548
# 1 BHK Independent House     333 sq ft     dda flat  Delhi  28.655981
# 1 BHK Apartment             450 sq ft       Nawada  Delhi  28.627590
#
#                           longitude  price currency  numBathrooms  \
# house_type
# ...

# %%
#crear nuevo data frame  a partir de los valores mayores o igules que 10,000
# 5. Crear nuevo DataFrame filtrado
df_nuevo = datos_casa_india[mask_precio_alto].copy()

# %%
# 7. Crear una serie con las direcciones
serie_direcciones = df_nuevo['location']

# Mostrar los resultados
display(serie_direcciones)
# Out:
# house_type
# 1 RK Studio Apartment                  Kalkaji
# 1 RK Studio Apartment        Mansarover Garden
# 3 BHK Independent House             Model Town
# 2 BHK Apartment               Sector 13 Rohini
# 3 BHK Apartment                      DLF Farms
#                                    ...
# 4 BHK Villa                       Sunder Nagar
# 5 BHK Independent House           Sunder Nagar
# 3 BHK Independent Floor     New Friends Colony
# 3 BHK Independent Floor     New Friends Colony
# 3 BHK Independent Floor     New Friends Colony
# Name: location, Length: 4827, dtype: object

# %%
#crear una serie con todas las direcciones de las casas

# %%
serie_todas_direcciones = datos_casa_india['location']
display(serie_todas_direcciones)
# Out:
# house_type
# 1 RK Studio Apartment                  Kalkaji
# 1 RK Studio Apartment        Mansarover Garden
# 2 BHK Independent Floor            Uttam Nagar
# 3 BHK Independent House             Model Town
# 2 BHK Apartment               Sector 13 Rohini
#                                    ...
# 4 BHK Villa                       Sunder Nagar
# 5 BHK Independent House           Sunder Nagar
# 3 BHK Independent Floor     New Friends Colony
# 3 BHK Independent Floor     New Friends Colony
# 3 BHK Independent Floor     New Friends Colony
# Name: location, Length: 5000, dtype: object

# %% [markdown]
# vicente, david adan y edgar moctezuma.
